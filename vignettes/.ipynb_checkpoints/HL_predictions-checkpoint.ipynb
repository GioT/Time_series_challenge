# %%
import sys
sys.path.append('../python')

# %%
# %load_ext autoreload
# %autoreload 2

import torch
from torch import nn
import torch.nn.functional as F
import torchvision as tv
from torchvision.transforms import v2
from diffusers import utils
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.utils.data as data
from tqdm import tqdm
from copy import deepcopy
import glob

# user's libraries found in ../python folder
from functions import *
from model import mlp,lstm,cnn_lstm

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = (
    'cuda' 
    if torch.cuda.is_available()
    else 'mps' if torch.backends.mps.is_available()
    else 'cpu'
)
print(device)
# Out:
# mps

# %% [markdown]
# TASK:<br>
# -train.csv: A training dataset comprising 60’000 photoplethysmography (PPG) signals sampled at 100 Hz (30-second duration each), as well as five additional features.
# First 3000 labelled columns (ppg_0,…, ppg_2999) correspond to the time series of the raw input optical signal.
# Last 5 labelled columns (feature_0,…,feature_4) correspond to engineered features containing relevant information.
# <br>-train_labels.csv: continuous labels.
# <br>-test.csv: A test dataset comprising 30’000 recordings with no labels, with the same format as the train.csv file.
# The password to download the data is: cheese! Please let us know if you experience any issues.
#
#
# The idea is to spend a maximum of 12 hours to:
#
# ·                     Use the training set to design a deep learning-based solution to predict the continuous labels of these PPG signals.
#
# ·                     Generate the outputs for the 30’000 recordings of the test dataset and share the obtained outputs as well as your code by email at the latest on the Monday 23rd of June (in the morning)

# %% [markdown]
# # CLASSES

# %%
class PARAMS():
    def __init__(self):
        self.input_size  = None
        self.hidden_size = None
        self.conv_c1     = None
        self.conv_c2     = None
        self.batch_size  = None
        self.n_epochs    = None

# %% [markdown]
# # FUNCTIONS

# %%
## in ../python/ folder

# %% [markdown]
# # MAIN

# %% [markdown]
# # 0. Imports

# %%
train_df = pd.read_csv('../data/train.csv')#.head(5000)
print(train_df.shape)
# train.head()
# Out:
# (60000, 3005)

# %%
train_l = pd.read_csv('../data/train_labels.csv')#.head(5000)
print(train_l.shape)
# train_l.head()
# Out:
# (60000, 1)

# %%
train_df['label'] = train_l['target']
print(train_df.shape)
# train_df
# Out:
# (60000, 3006)

# %% [markdown]
# ## 1. Data Pre-processing

# %%
# %%time
## get train, validation & test sets from training data

X = train_df.drop('label',axis=1)
n = len(X) # size of train dataset
y = train_df[['label']]

# train-validation-test split for time series
X_raw_train, X_raw_val, X_raw_test = X[0:int(n*0.7)], X[int(n*0.7):int(n*0.9)], X[int(n*0.9):]
y_raw_train, y_raw_val, y_raw_test = y[0:int(n*0.7)], y[int(n*0.7):int(n*0.9)], y[int(n*0.9):]

# Normalize dataset
train_mean = X_raw_train.mean()
train_std  = X_raw_train.std()

X_raw_train = (X_raw_train - train_mean) / train_std
X_raw_val   = (X_raw_val - train_mean) / train_std
X_raw_test  = (X_raw_test - train_mean) / train_std
# Out:
# CPU times: user 690 ms, sys: 1.32 s, total: 2.01 s
# Wall time: 1.06 s

# %%
# %%time
## make datasets to be passed to DNNs
lookback = 1
X_train, y_train = create_dataset(X_raw_train, lookback=lookback),create_dataset(y_raw_train, lookback=lookback)
X_val, y_val     = create_dataset(X_raw_val, lookback=lookback),  create_dataset(y_raw_val, lookback=lookback)
X_test, y_test   = create_dataset(X_raw_test, lookback=lookback), create_dataset(y_raw_test, lookback=lookback)
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([42000, 1, 3005]) torch.Size([42000, 1, 1])
# torch.Size([12000, 1, 3005]) torch.Size([12000, 1, 1])
# torch.Size([6000, 1, 3005]) torch.Size([6000, 1, 1])
# CPU times: user 9.25 s, sys: 142 ms, total: 9.4 s
# Wall time: 9.39 s

# %% [markdown]
# ## 2. Training the Deep Learning Models to predict label

# %%
# if 11<3:
#     ## single forward pass in batches to make sure everything works!
#     h_s             = 32
#     input_size      = X_train.shape[-1]
#     conv_c1         = 4 # number of channels for conv1
#     conv_c2         = 4 # number of channels for conv1
#     batch_size      = 16
#     model           = cnn_lstm(h_s,input_size,conv_c1,conv_c2) # lstm(h_s, input_size) # mlp(input_size) # 
#     optimizer       = optim.Adam(model.parameters(),lr=1e-5,)
#     loss_fn         = nn.MSELoss()
#     loader          = data.DataLoader(data.TensorDataset(X_train, y_train), shuffle=True, batch_size=batch_size)
     
#     n_epochs = 1
#     for epoch in tqdm(range(n_epochs)):
#         model.train()
#         for X_batch, y_batch in loader:
#             y_pred = model(X_batch)#.reshape(y_batch.shape[0],1)
#             break
# y_pred.shape

# %%
# %%time
# Setting parameters for the different runs
params = PARAMS()
params.hidden_size = 32 # size of lstm hidden layer
params.input_size  = X_train.shape[-1]
params.batch_size  = 64
params.conv_c1     = 4 # number of channels for conv1
params.conv_c2     = 4 # number of channels for conv1
params.n_epochs    = 100
loss_fn            = nn.MSELoss()

# model           = cnn_lstm(h_s,input_size,conv_c1,conv_c2) # mlp(input_size) # lstm(h_s, input_size) #
models = {'mlp':mlp,
          'lstm':lstm,
          'cnn_lstm':cnn_lstm
         }
run_seeds = [0,9,42]

## we will train each of the 3 model type 3 times (3 different seeds), record metrics and save model checkpoints every 10 epochs
for mod in models.keys():
    for run_seed in run_seeds:
        
        # set seed reproducibility
        torch.manual_seed(run_seed)
        loader    = data.DataLoader(data.TensorDataset(X_train, y_train), shuffle=True, batch_size=batch_size)
        model     = models[mod](params)
        optimizer = optim.Adam(model.parameters(),lr=1e-4,)

        print('>> training',mod,'with seed:',run_seed)

        metrics = [] # stores training and validation rmse per epochs
        
        for epoch in tqdm(range(params.n_epochs)):
            model.train()
            for X_batch, y_batch in loader:
                y_pred = model(X_batch)#.reshape(y_batch.shape[0],1)
                loss = loss_fn(y_pred, y_batch)
                # print(y_pred)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            model.eval()
            with torch.no_grad():
                # Checking rsme on whole training set
                y_pred_t   = model(X_train)#.reshape(y_train.shape[0],1)
                train_rmse = np.round(np.sqrt(loss_fn(y_pred_t, y_train)).detach().numpy(),2)
                # Checking rsme on validation set
                y_pred_v = model(X_val)#.reshape(y_val.shape[0],1)
                val_rmse = np.round(np.sqrt(loss_fn(y_pred_v, y_val)).detach().numpy(),2)
                # save model performance:
                metrics.append([mod,run_seed,epoch,train_rmse,val_rmse])
                
            ## save model params every 10 epochs:
            # Validation
            if epoch % 10 == 0:
                model_params_path = '../output/model_params/'+mod+'_e_'+str(epoch)+'_seed_'+str(run_seed)+'_trainRMSE_'+str(train_rmse)+'_valRMSE_'+str(val_rmse)
                torch.save(model.state_dict(), model_params_path)
                print('> saved model params to path',model_params_path)
                # print("Epoch %d: train RMSE %.4f, validation RMSE %.4f" % (epoch, train_rmse, val_rmse))
        
        # save performance to file at each epoch:
        metric_path = '../output/training_output/'+mod+'_e_'+str(epoch)+'_seed_'+str(run_seed)+'.csv'
        metrics = pd.DataFrame(metrics,columns=['model','seed','epoch','trainRMSE','valRMSE'])
        metrics.to_csv(metric_path,index=False,sep=',')
# Out:
# >> training mlp with seed: 0
#   1%|▍                                          | 1/100 [00:00<00:56,  1.76it/s]
# > saved model params to path ../output/model_params/mlp_e_0_seed_0_trainRMSE_3.73_valRMSE_3.85
#  11%|████▌                                     | 11/100 [00:06<00:49,  1.82it/s]
# > saved model params to path ../output/model_params/mlp_e_10_seed_0_trainRMSE_2.57_valRMSE_2.99
#  21%|████████▊                                 | 21/100 [00:11<00:44,  1.77it/s]
# > saved model params to path ../output/model_params/mlp_e_20_seed_0_trainRMSE_1.82_valRMSE_2.47
#  31%|█████████████                             | 31/100 [00:17<00:39,  1.75it/s]
# > saved model params to path ../output/model_params/mlp_e_30_seed_0_trainRMSE_1.24_valRMSE_2.07
#  41%|█████████████████▏                        | 41/100 [00:23<00:32,  1.79it/s]
# > saved model params to path ../output/model_params/mlp_e_40_seed_0_trainRMSE_1.3_valRMSE_2.15
# ...

# %%
## show training results:
final_result = pd.concat([pd.read_csv(x) for x in glob.glob('../output/training_output/mlp*')])
plt.grid(axis='y')
sns.lineplot(data = final_result,x='epoch',y='trainRMSE',color='#ff0051',label='train')
sns.lineplot(data = final_result,x='epoch',y='valRMSE',color='#008bfb',label='validation')
plt.ylim(0,5)
plt.title('Training the mlp')
plt.legend()
plt.gca().set_ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %%
## show training results:
final_result = pd.concat([pd.read_csv(x) for x in glob.glob('../output/training_output/cnn_lstm*')])
plt.grid(axis='y')
sns.lineplot(data = final_result,x='epoch',y='trainRMSE',color='#ff0051',label='train')
sns.lineplot(data = final_result,x='epoch',y='valRMSE',color='#008bfb',label='validation')
plt.title('Training the cnn lstm')
plt.ylim(0,5)
plt.legend()
plt.gca().set_ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %% [markdown]
# We can see the performance of the cnn-lstm is slightly better on the validation sets, we therefore chose the checkpoint at epoch 20 for the predictions on the remaining test set

# %% [markdown]
# ## 3. Checking performance of best models

# %%
## Selecting best model checkpoint to plot
best_model = { 'mlp':[mlp,'../output/model_params/mlp_e_30_seed_0_trainRMSE_1.24_valRMSE_2.07'],
                'lstm':[lstm,],
                'cnn_lstm':[cnn_lstm,'../output/model_params/cnn_lstm_e_20_seed_9_trainRMSE_1.07_valRMSE_1.78']
             }
selected_model = 'cnn_lstm' # manually change me

model = best_model[selected_model][0](params)
model.load_state_dict(torch.load(best_model[selected_model][1], weights_only=True))
model.eval()
# Out:
# cnn_lstm(
#   (conv1): Conv1d(1, 4, kernel_size=(4,), stride=(1,), padding=(2,))
#   (conv2): Conv1d(4, 4, kernel_size=(4,), stride=(1,), padding=(2,))
#   (maxpool): MaxPool1d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=12020, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (lstm): LSTM(128, 32, batch_first=True)
#   (linear): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
## plot training set results:
with torch.no_grad():
    y_real = y_train[:, -1, :]
    y_hat  = model(X_train)[:, -1, :] # you take the last prediction (last of 2nd element of 3D tensor)
    print('>> RMSE train:',np.sqrt(loss_fn(y_hat, y_real)).detach().numpy() )
# plot
plt.figure(figsize=(10,5))
plt.plot(y_real[:200], c='#ff0051',marker='x',label='ground truth')
plt.plot(y_hat[:200], c='#008bfb',marker='x',label='prediction')
plt.legend()
plt.show()
# Out:
# >> RMSE train: 1.0687529

# %%
## plot validation set results:
with torch.no_grad():
    y_real = y_val[:, -1, :]
    y_hat  = model(X_val)[:, -1, :] # you take the last prediction (last of 2nd element of 3D tensor)
    print('>> RMSE validation:',np.sqrt(loss_fn(y_hat, y_real)).detach().numpy() )
# plot
plt.figure(figsize=(10,5))
plt.plot(y_real[:100], c='#ff0051',marker='x')
plt.plot(y_hat[:100], c='#008bfb',marker='x')
plt.show()
# Out:
# >> RMSE validation: 1.7772367

# %%
## plot test set results:
with torch.no_grad():
    y_real = y_test[:, -1, :]
    y_hat  = model(X_test)[:, -1, :] # you take the last prediction (last of 2nd element of 3D tensor)
    print('>> RMSE test set:',np.sqrt(loss_fn(y_hat, y_real)).detach().numpy() )
# plot
plt.figure(figsize=(10,5))
plt.plot(y_real[:100], c='#ff0051',marker='x')
plt.plot(y_hat[:100], c='#008bfb',marker='x')
plt.show()
# Out:
# >> RMSE test set: 1.8211955

# %%
## check Baseline model (using the last data
y_val_np = y_val.detach().numpy().flatten()
y_val_nofirst = torch.tensor(np.delete(y_val_np, 0))
y_val_nolast  = torch.tensor(np.delete(y_val_np, -1))

loss_fn       = nn.MSELoss()
base_rmse     = np.sqrt(loss_fn(y_val_nofirst, y_val_nolast))
print('>> Baseline rmse:',base_rmse.numpy())
# Out:
# >> Baseline rmse: 7.1585474

# %% [markdown]
# ## 4. Prediction on final 30K Test Set:

# %%
# %%time
## import final test set and pre-process data in the same way as above
X_test_final = pd.read_csv('../data/test.csv')
print(X_test_final.shape)

# normalization
X_test_final = (X_test_final - train_mean) / train_std
# Out:
# (30000, 3005)
# CPU times: user 3.32 s, sys: 941 ms, total: 4.27 s
# Wall time: 3.84 s

# %%
# check whether test data distribution matches that of train dataset
cols2plot = ['ppg_0','ppg_1','features_0','features_1','features_2','features_3','features_4']
fig, axes = plt.subplots(nrows=2, ncols=3, dpi=100, figsize=(15, 10))

sns.kdeplot(X_test_final[cols2plot[0]],c='blue',ax=axes[0, 0],label='test')
sns.kdeplot(X_raw_train[cols2plot[0]],c='red',ax=axes[0, 0],label='train')
# plt.legend()
sns.kdeplot(X_test_final[cols2plot[1]],c='blue',ax=axes[0, 1])
sns.kdeplot(X_raw_train[cols2plot[1]],c='red',ax=axes[0, 1])
sns.kdeplot(X_test_final[cols2plot[2]],c='blue',ax=axes[0, 2])
sns.kdeplot(X_raw_train[cols2plot[2]],c='red',ax=axes[0, 2])
sns.kdeplot(X_test_final[cols2plot[3]],c='blue',ax=axes[1, 0])
sns.kdeplot(X_raw_train[cols2plot[3]],c='red',ax=axes[1, 0])
sns.kdeplot(X_test_final[cols2plot[4]],c='blue',ax=axes[1, 1])
sns.kdeplot(X_raw_train[cols2plot[4]],c='red',ax=axes[1, 1])
sns.kdeplot(X_test_final[cols2plot[5]],c='blue',ax=axes[1, 2])
sns.kdeplot(X_raw_train[cols2plot[5]],c='red',ax=axes[1, 2])
# Out:
# <Axes: xlabel='features_3', ylabel='Density'>

# %% [markdown]
# It looks like the test and train datasets have almost identidical distributions, we can then proceed to predict the labels of the test set!

# %%
# %%time
## predicting labels for test set:

# convert test data to tensors:
lookback = 1
X_test_final = create_dataset(X_test_final, lookback=lookback,shift=1)
print(X_test_final.shape)

# select model to use:
selected_model = 'cnn_lstm' # manually change me
model          = best_model[selected_model][0](params)
model.load_state_dict(torch.load(best_model[selected_model][1], weights_only=True))
print('>> loaded best model at',best_model[selected_model][1])
model.eval()
# Out:
# torch.Size([30000, 1, 3005])
# >> loaded best model at ../output/model_params/cnn_lstm_e_20_seed_9_trainRMSE_1.07_valRMSE_1.78
# CPU times: user 4.51 s, sys: 117 ms, total: 4.62 s
# Wall time: 4.63 s
# cnn_lstm(
#   (conv1): Conv1d(1, 4, kernel_size=(4,), stride=(1,), padding=(2,))
#   (conv2): Conv1d(4, 4, kernel_size=(4,), stride=(1,), padding=(2,))
#   (maxpool): MaxPool1d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=12020, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (lstm): LSTM(128, 32, batch_first=True)
#   (linear): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
# %%time
with torch.no_grad():
    y_hat_final  = model(X_test_final)[:, -1, :] # you take the last prediction (last of 2nd element of 3D tensor)
    # print('>> RMSE validation:',np.sqrt(loss_fn(y_hat, y_real)).detach().numpy() )
predictions = y_hat_final.detach().numpy().flatten()
# Out:
# CPU times: user 7.19 s, sys: 1.19 s, total: 8.38 s
# Wall time: 3.77 s

# %%
## save predictions to file
pd.DataFrame(predictions,columns=['y_pred']).to_csv('../output/test_predictions.csv',index=False,sep=',')
